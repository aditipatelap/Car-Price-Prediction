# %% [markdown]
# # Problem Statement
#
# The price of a car depends on a lot of factors like the goodwill of the brand of the car, features of the car, horsepower and the mileage it gives and many more. Car price prediction is one of the major research areas in machine learning. So if you want to learn how to train a car price prediction model then this project is for you.

# %% [markdown]
# ## Solution:
#
# In this notebook, I'll work with the [dataset](https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv) about used cars and their prices.

# %% [markdown]
# ## Import libraries
#
# I'm importing datetime to handle year, numpy to work with arrays and pandas to read in the dataset files, matplotlib & seaborn for plotting and sklearn for various machine learning models.

# %%
import datetime

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Loading Dataset
# First read the dataset and get information from it.

# %%
dataset = pd.read_csv("data/CarPrice.csv")
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Exploring the descriptive statistics of the variables.

# %%
dataset.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# ### Displaying column information

# %%
# Get summary of dataframe
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
# Display all the car names (without repitition)
dataset.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %% [markdown]
# ### Drop features that are not required to build model

# %%
# In symboling column - it's not effect on car price so we can remove it.
df1 = dataset.drop(labels=['CarName', 'symboling', 'car_ID', 'enginetype', 'fuelsystem'], axis=1)

# %% [markdown]
# ### Check for any missing value in data set and treat it

# %%
df1.isna().sum()
# Out:
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# cylindernumber      0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# There is no NAN value in the dataset.

# %% [markdown]
# ## Data exploration
# - "price" column

# %%
# Plot the box plot of the 'price' column to find outliers
plt.figure(figsize=[3,4])
df1.boxplot('price')
plt.title("Car Price Distribution Box-Plot")
# Out:
# Text(0.5, 1.0, 'Car Price Distribution Box-Plot')

# %%
# Find how many outlier are there in (numeric)column - using z score normalization
def findOutliers(df):
    # Select numeric columns
    numeric_columns = df.select_dtypes(include=['number']).columns
    print("selected columns are:\n", numeric_columns)
    
    # Set the threshold for Z-scores
    threshold = 2
    
    for column in numeric_columns:
        z_scores = (df[column] - df[column].mean()) / df[column].std()
        outliers = df[z_scores.abs() > threshold]
        print("Outliers in column '{}':".format(column), len(outliers))
        
findOutliers(df1)
# Out:
# selected columns are:
#  Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')
# Outliers in column 'wheelbase': 12
# Outliers in column 'carlength': 13
# Outliers in column 'carwidth': 15
# Outliers in column 'carheight': 12
# Outliers in column 'curbweight': 10
# Outliers in column 'enginesize': 7
# Outliers in column 'boreratio': 4
# Outliers in column 'stroke': 9
# Outliers in column 'compressionratio': 20
# Outliers in column 'horsepower': 8
# Outliers in column 'peakrpm': 7
# Outliers in column 'citympg': 3
# Outliers in column 'highwaympg': 9
# Outliers in column 'price': 15

# %% [markdown]
# ## Feature Selection
#
# Feature selection simplified models, improves speed and prevent a series of unwanted issues arising from having many features

# %%
unique_values = df1['fueltype'].unique()
unique_values
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df1.head()
# Out:
#   fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0      gas        std        two  convertible        rwd          front
# 1      gas        std        two  convertible        rwd          front
# 2      gas        std        two    hatchback        rwd          front
# 3      gas        std       four        sedan        fwd          front
# 4      gas        std       four        sedan        4wd          front
#
#    wheelbase  carlength  carwidth  carheight  ...  cylindernumber enginesize  \
# 0       88.6      168.8      64.1       48.8  ...            four        130
# 1       88.6      168.8      64.1       48.8  ...            four        130
# 2       94.5      171.2      65.5       52.4  ...             six        152
# 3       99.8      176.6      66.2       54.3  ...            four        109
# 4       99.4      176.6      66.4       54.3  ...            five        136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 21 columns]

# %%
# copy the updated dataframe
df2 = df1.copy()

for column in df2.columns:
    if df2[column].dtype == "object":
        encoder = LabelEncoder()
        df2[column] = encoder.fit_transform(df2[column])
        
df2.head()
# Out:
#    fueltype  aspiration  doornumber  carbody  drivewheel  enginelocation  \
# 0         1           0           1        0           2               0
# 1         1           0           1        0           2               0
# 2         1           0           1        2           2               0
# 3         1           0           0        3           1               0
# 4         1           0           0        3           0               0
#
#    wheelbase  carlength  carwidth  carheight  ...  cylindernumber  enginesize  \
# 0       88.6      168.8      64.1       48.8  ...               2         130
# 1       88.6      168.8      64.1       48.8  ...               2         130
# 2       94.5      171.2      65.5       52.4  ...               3         152
# 3       99.8      176.6      66.2       54.3  ...               2         109
# 4       99.4      176.6      66.4       54.3  ...               1         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Correlation of the Features

# %% [markdown]
# # Correated Features with target variable
# print('\n--Correated Features with target variable--\n')
# print(abs(df2.corrwith(df2['price'])))

# %%
# can find relation like this also
df2.corr()
# Out:
#                   fueltype  aspiration  doornumber   carbody  drivewheel  \
# fueltype          1.000000   -0.401397    0.191491 -0.147853   -0.132257
# aspiration       -0.401397    1.000000   -0.031792  0.063028    0.066465
# doornumber        0.191491   -0.031792    1.000000 -0.680358    0.098954
# carbody          -0.147853    0.063028   -0.680358  1.000000   -0.155745
# drivewheel       -0.132257    0.066465    0.098954 -0.155745    1.000000
# enginelocation    0.040070   -0.057191    0.137757 -0.277009    0.147865
# wheelbase        -0.308346    0.257611   -0.447357  0.401362    0.459745
# carlength        -0.212679    0.234539   -0.398568  0.334433    0.485649
# carwidth         -0.233880    0.300567   -0.207168  0.131710    0.470751
# carheight        -0.284631    0.087311   -0.552208  0.568534   -0.019719
# curbweight       -0.217275    0.324902   -0.197379  0.128467    0.575111
# cylindernumber    0.110617   -0.133119    0.154322 -0.048408    0.223238
# enginesize       -0.069594    0.108217   -0.020742 -0.073352    0.524307
# boreratio        -0.054451    0.212614   -0.119258  0.010549    0.481827
# stroke           -0.241829    0.222982    0.011082 -0.015325    0.071591
# compressionratio -0.984356    0.295541   -0.177888  0.136243    0.127479
# horsepower        0.163926    0.241685    0.126947 -0.153928    0.518686
# peakrpm           0.476883   -0.183383    0.247668 -0.109643   -0.039417
# citympg          -0.255963   -0.202362    0.012417  0.031697   -0.449581
# highwaympg       -0.191392   -0.254416    0.036330 -0.007170   -0.452220
# price            -0.105679    0.177926   -0.031835 -0.083976    0.577992
#
#                   enginelocation  wheelbase  carlength  carwidth  carheight  \
# fueltype                0.040070  -0.308346  -0.212679 -0.233880  -0.284631
# aspiration             -0.057191   0.257611   0.234539  0.300567   0.087311
# doornumber              0.137757  -0.447357  -0.398568 -0.207168  -0.552208
# carbody                -0.277009   0.401362   0.334433  0.131710   0.568534
# drivewheel              0.147865   0.459745   0.485649  0.470751  -0.019719
# enginelocation          1.000000  -0.187790  -0.050989 -0.051698  -0.106234
# wheelbase              -0.187790   1.000000   0.874587  0.795144   0.589435
# carlength              -0.050989   0.874587   1.000000  0.841118   0.491029
# carwidth               -0.051698   0.795144   0.841118  1.000000   0.279210
# carheight              -0.106234   0.589435   0.491029  0.279210   1.000000
# curbweight              0.050468   0.776386   0.877728  0.867032   0.295572
# cylindernumber          0.135541  -0.184596  -0.109585 -0.194074  -0.283845
# enginesize              0.196826   0.569329   0.683360  0.735433   0.067149
# boreratio               0.185042   0.488750   0.606454  0.559150   0.171071
# stroke                 -0.138455   0.160959   0.129533  0.182942  -0.055307
# compressionratio       -0.019762   0.249786   0.158414  0.181129   0.261214
# horsepower              0.317839   0.353294   0.552623  0.640732  -0.108802
# peakrpm                 0.198461  -0.360469  -0.287242 -0.220012  -0.320411
# citympg                -0.153487  -0.470414  -0.670909 -0.642704  -0.048640
# highwaympg             -0.102026  -0.544082  -0.704662 -0.677218  -0.107358
# price                   0.324973   0.577816   0.682920  0.759325   0.119336
#
#                   ...  cylindernumber  enginesize  boreratio    stroke  \
# fueltype          ...        0.110617   -0.069594  -0.054451 -0.241829
# aspiration        ...       -0.133119    0.108217   0.212614  0.222982
# doornumber        ...        0.154322   -0.020742  -0.119258  0.011082
# carbody           ...       -0.048408   -0.073352   0.010549 -0.015325
# drivewheel        ...        0.223238    0.524307   0.481827  0.071591
# enginelocation    ...        0.135541    0.196826   0.185042 -0.138455
# wheelbase         ...       -0.184596    0.569329   0.488750  0.160959
# carlength         ...       -0.109585    0.683360   0.606454  0.129533
# carwidth          ...       -0.194074    0.735433   0.559150  0.182942
# carheight         ...       -0.283845    0.067149   0.171071 -0.055307
# curbweight        ...       -0.047127    0.850594   0.648480  0.168790
# cylindernumber    ...        1.000000   -0.085613  -0.032844 -0.050088
# enginesize        ...       -0.085613    1.000000   0.583774  0.203129
# boreratio         ...       -0.032844    0.583774   1.000000 -0.055909
# stroke            ...       -0.050088    0.203129  -0.055909  1.000000
# compressionratio  ...       -0.064701    0.028971   0.005197  0.186110
# horsepower        ...        0.115612    0.809769   0.573677  0.080940
# peakrpm           ...        0.222731   -0.244660  -0.254976 -0.067964
# citympg           ...       -0.126422   -0.653658  -0.584532 -0.042145
# highwaympg        ...       -0.085897   -0.677470  -0.587012 -0.043931
# price             ...       -0.027628    0.874145   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# fueltype                 -0.984356    0.163926  0.476883 -0.255963
# aspiration                0.295541    0.241685 -0.183383 -0.202362
# doornumber               -0.177888    0.126947  0.247668  0.012417
# carbody                   0.136243   -0.153928 -0.109643  0.031697
# drivewheel                0.127479    0.518686 -0.039417 -0.449581
# enginelocation           -0.019762    0.317839  0.198461 -0.153487
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# cylindernumber           -0.064701    0.115612  0.222731 -0.126422
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# fueltype           -0.191392 -0.105679
# aspiration         -0.254416  0.177926
# doornumber          0.036330 -0.031835
# carbody            -0.007170 -0.083976
# drivewheel         -0.452220  0.577992
# enginelocation     -0.102026  0.324973
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# cylindernumber     -0.085897 -0.027628
# enginesize         -0.677470  0.874145
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000
#
# [21 rows x 21 columns]

# %%
# plot the correlation (heat map)
plt.figure(figsize=[20,20])
sns.heatmap(df2.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Feature Importance
#
# - Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards our Target variable.

# %% [markdown]
# ## Training & Testing
#
# Let's first split the dataset into train and test datasets.
#
# - **from sklearn.metrics import r2_score**: It's use for measuring **regression** score.
# - **from sklearn.metrics import accuracy_score**: It's use for measuring **classification** score.

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split

#slicing the dataset and reomoving the selling price for training the model
x = df2.iloc[:, :-1]
#storing the selling price for checking..as this is the value to be predicted
y = df2.iloc[:, -1]

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 50)

# %% [markdown]
# ### Linear Regression model
#
# Linear regression is a statistical model that predicts a dependent variable from one or more independent variables.\
# The equation for simple linear regression is:
# y = b0 + b1 * x

# %%
from sklearn.linear_model import LinearRegression

linearRegression = LinearRegression()
linearRegression.fit(xtrain, ytrain)
predictions = linearRegression.predict(xtest)
accuracy_linear = r2_score(ytest, predictions)

# %% [markdown]
# ### Decision Tree Regression model
#
# Decision tree regression is a supervised learning algorithm that uses a tree-like structure to predict a continuous value. The tree is built by recursively splitting the data into smaller and smaller subsets, until each subset contains only data points that are very similar to each other. The prediction for a new data point is then made by following the tree from the root node to the leaf node that corresponds to the new data point.

# %%
from sklearn.tree import DecisionTreeRegressor

decisionTreeRegressor = DecisionTreeRegressor()
decisionTreeRegressor.fit(xtrain, ytrain)
predictions = decisionTreeRegressor.predict(xtest)
accuracy_dtr = r2_score(ytest, predictions)

# %% [markdown]
# ### Random Forest model
#
# A random forest model is an ensemble learning method for classification, regression, and other tasks that operates by constructing a multitude of decision trees at training time. For classification tasks, the output of the random forest is the class selected by most trees. For regression tasks, the mean or average prediction of the individual trees is returned. The idea behind this ensemble approach is to reduce overfitting and improve the overall predictive performance. Random forests generally outperform decision trees, but their accuracy is lower than gradient boosted trees.
#
# Here, are the steps on how random forest works:
# 1. Bootstrapping:
# Random samples are taken from the training dataset with replacement. This means that some data points may be selected more than once, while others may not be selected at all.
# 2. Building decision trees:
# Decision trees are built on each bootstrapped sample. Each tree is built using a random subset of features.
# 3. Voting:
# The predictions from each decision tree are combined using majority voting for classification tasks and averaging for regression tasks.

# %%
from sklearn.ensemble import RandomForestRegressor

randomForestRegressor = RandomForestRegressor()
randomForestRegressor.fit(xtrain, ytrain)
predictions = randomForestRegressor.predict(xtest)
accuracy_rf = r2_score(ytest, predictions)

# %% [markdown]
# ### Accuracy of the models:

# %%
print("Linear Regression model:", "{:.4f}".format(accuracy_linear))
print("Random Forest model:", "{:.4f}".format(accuracy_rf))
print("Decision Tree Regression model:", "{:.4f}".format(accuracy_dtr))
# Out:
# Linear Regression model: 0.8242
# Random Forest model: 0.9195
# Decision Tree Regression model: 0.8699

# %% [markdown]
# Here we can see Random Forest model gives the higher accuracy of the testing dataset.\
# Let's select the model and save it.

# %% [markdown]
# ## Save Model

# %%
from joblib import dump

# Save the model to a file
filename = 'model.joblib'
dump(randomForestRegressor, filename)
# Out:
# ['model.joblib']

# %% [markdown]
# ## Load the Model

# %%
from joblib import load

# Load the saved model from file
filename = 'model.joblib'
model = load(filename)

# %%
# model.predict([df2.loc[49,['fueltype', "aspiration", 'doornumber', 'carbody', 'drivewheel',
#        'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]])

# %%
# df1.loc[49]
